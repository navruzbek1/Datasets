# %% [markdown]
# <a href="https://colab.research.google.com/github/navruzbekgit/navruzbekgit/blob/main/disp_his_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Ushbu amaliyotda uybor.uz saytidan yuklab olingan ma'lumotlar tahlili bilan shu'gullanamiz.

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/blob/main/uybor_scrapping.csv?raw=true")
df.head()
# Out:
#                                             location  ...        lng
# 0  город Ташкент, Юнусабадский район, Юнусабад 8-...  ...  69.281049
# 1  город Ташкент, Яккасарайский район, 1-й тупик ...  ...  69.261104
# 2  город Ташкент, Чиланзарский район, Чиланзар 2-...  ...  69.223683
# 3  город Ташкент, Чиланзарский район, Чиланзар 9-...  ...  69.196862
# 4  город Ташкент, Чиланзарский район, площадь Актепа  ...  69.210831
#
# [5 rows x 9 columns]

# %% [markdown]
# #### Yuqoridagi jadvalda Toshkent shahridagi sotildagian uylar haqida ma'lumotlar jamlangan.
#
# ### 1-VAZIFA. Uylarning narxi taqsimotini grafikda ko'rsating

# %%
#JAVOBINGIZNI SHUYERGA YOZING
sns.displot(data=df,x='price',height=5,aspect=2)
plt.show()

# %% [markdown]
# ### Jadvalda 7000 dan oshiq uy bor, aksar uylarning narxi 200000$ dan kam. Keling noodatiy katta qiymatlarni tashlab yuboramiz va yuqoridagi chizmani qaytadan chizamiz.

# %%
#JAVOBINGIZNI SHUYERGA YOZING
df=df[df.price<200000]
sns.displot(data=df,x="price",height=5,aspect=2)
plt.show()

# %% [markdown]
# ### 2-VAZIFA. Uylarning maydoni taqsimoti grafigini chizing

# %%
# JAVOB UCHUN JOY

# %%
#@title Kutilgan natija
plt.figure(figsize=(10,6))
sns.histplot(data=df, x='size')
plt.show()

# %% [markdown]
# ### 3-VAZIFA. Uylarning xonalar soni taqsimotini chiqaring.

# %%
# JAVOB UCHUN JOY
sns.displot(data=df,x="rooms",height=5,aspect=2,hue="district",multiple="stack")
plt.show()

# %% [markdown]
# 6 xonadan ortiq uylarni tashlab yuboramiz.

# %%
df = df[df['rooms']<7]

# %% [markdown]
# ### 4-VAZIFA. Uylarning narxi taqsimotini xonalar soniga bog'lab chiqaramiz.

# %%
# JAVOBNI SHUYERGA YOZING
sns.displot(data=df,x='price',hue='rooms',height=5,aspect=2,multiple="stack",palette='Accent')
plt.show()

# %% [markdown]
# ### 4.1 Grafik tushunarsiz chiqdi. Keling faqatgina 1,2,3 xonali uylarning narx bo'yicha taqsimotini chizamiz.

# %%
# JAVOBNI SHUYERGA YOZING
df3=df[(df.rooms==1) | (df.rooms==2) | (df.rooms==3)]
sns.displot(data=df3,x='price',hue='rooms',palette='Reds',height=5,aspect=2)
plt.show()

# %% [markdown]
# ### 5-VAZIFA. 4,5,6 xonali uylar uchun narx taqsimotini alohida grafiklarda chizing

# %%
# JAVOB UCHUN JOY
sns.displot(data=df[(df.rooms>3) | (df.rooms<7)],x="price",hue='rooms',height=5,aspect=2,palette='Reds')

# %%
#@title Kutilgan natija
sns.displot(data=df[df['rooms']>3], x="price", col="rooms", height=5, aspect=1)
plt.show()

# %% [markdown]
# ## 6-VAZIFA. Uylarning maydoni taqsimoti KDE grafigini chizing

# %%
# JAVOB UCHUN JOY
sns.kdeplot(data=df,x='size')

# %% [markdown]
# ## 7-VAZIFA. Uylarning maydoni taqsimotini KDE va taqsimotini birlashtirib chizing.

# %%
# JAVOB UCHUN JOY
sns.displot(data=df,x="size",kde=True
            ,height=5,aspect=2)
plt.show()

# %% [markdown]
# ## 8-VAZIFA. Uylarning narxi va xonalari soni uchun (2,3,5 xonali) KDE chizing.

# %%
# JAVOB UCHUN JOY
plt.figure(figsize=(12,6))
sns.kdeplot(data=df[(df.rooms>1) | (df.rooms<5)],shade=True,x="price",hue='rooms')
plt.show()

# %% [markdown]
# ## 9-VAZIFA. Uylarning maydoni uchun kumulyativ taqsimot grafigini chizing (CDF)

# %%
# JAVOB UCHUN JOY
sns.ecdfplot(data=df,x='size')
plt.grid(which="major")
plt.minorticks_on()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 10-VAZIFA. Yuqoridagi grafikni uylarning narxi uchun chizing.

# %%
# JAVOB UCHUN JOY
sns.displot(data=df, x="price", kind="ecdf", height=5, aspect=2)
plt.xticks(rotation=90)
plt.grid(which='both') # setka (major, minor, both) qiymatlarini berib ko'ring
plt.minorticks_on()
plt.show()
